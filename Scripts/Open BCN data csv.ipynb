# %%
import pandas as pd
df = pd.read_csv('/home/sergio/Documents/CSIC/data/2017_tramer_mapa_estrategic_soroll_bcn.csv')
df.head(3)
# Out:
#       TRAM        TOTAL_D        TOTAL_E        TOTAL_N      TOTAL_DEN  \
# 0  T04719W  70 - 75 dB(A)  65 - 70 dB(A)  60 - 65 dB(A)  70 - 75 dB(A)
# 1  T19941Z  45 - 50 dB(A)  45 - 50 dB(A)     < 40 dB(A)  45 - 50 dB(A)
# 2  T18111R  55 - 60 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)  55 - 60 dB(A)
#
#        TRANSIT_D      TRANSIT_E      TRANSIT_N    TRANSIT_DEN        GI_TR_D  \
# 0  70 - 75 dB(A)  65 - 70 dB(A)  60 - 65 dB(A)  70 - 75 dB(A)     < 40 dB(A)
# 1  40 - 45 dB(A)  40 - 45 dB(A)     < 40 dB(A)  45 - 50 dB(A)     < 40 dB(A)
# 2  55 - 60 dB(A)  55 - 60 dB(A)  50 - 55 dB(A)  55 - 60 dB(A)  40 - 45 dB(A)
#
#    ...    INDUST_D    INDUST_E    INDUST_N  INDUST_DEN     VIANANTS_D  \
# 0  ...  < 40 dB(A)  < 40 dB(A)  < 40 dB(A)  < 40 dB(A)     < 40 dB(A)
# 1  ...  < 40 dB(A)  < 40 dB(A)  < 40 dB(A)  < 40 dB(A)  45 - 50 dB(A)
# 2  ...  < 40 dB(A)  < 40 dB(A)  < 40 dB(A)  < 40 dB(A)     < 40 dB(A)
#
#       VIANANTS_E       OCI_N     PATIS_D     PATIS_E  \
# ...

# %%
df.columns
# Out:
# Index(['TRAM', 'TOTAL_D', 'TOTAL_E', 'TOTAL_N', 'TOTAL_DEN', 'TRANSIT_D',
#        'TRANSIT_E', 'TRANSIT_N', 'TRANSIT_DEN', 'GI_TR_D', 'GI_TR_E',
#        'GI_TR_N', 'GI_TR_DEN', 'FFCC_D', 'FFCC_E', 'FFCC_N', 'FFCC_DEN',
#        'INDUST_D', 'INDUST_E', 'INDUST_N', 'INDUST_DEN', 'VIANANTS_D',
#        'VIANANTS_E', 'OCI_N', 'PATIS_D', 'PATIS_E', 'GEOM_WKT'],
#       dtype='object')

# %%
'TRAM':
    
#ruido total
'TOTAL_D':
'TOTAL_E', 
'TOTAL_N', 
'TOTAL_DEN', 

#ruido transito viario
'TRANSIT_D',
'TRANSIT_E', 
'TRANSIT_N', 
'TRANSIT_DEN', 


'GI_TR_D', 
'GI_TR_E',
'GI_TR_N',
'GI_TR_DEN', 
'FFCC_D', 
'FFCC_E', 
'FFCC_N', 
'FFCC_DEN',
'INDUST_D', 'INDUST_E', 'INDUST_N', 'INDUST_DEN', 

'VIANANTS_D',
       'VIANANTS_E', 
    
    'OCI_N',
    
    'PATIS_D', 'PATIS_E', 
    
    'GEOM_WKT'
    
    D = Día
    E = Vespre
    N = Noche
